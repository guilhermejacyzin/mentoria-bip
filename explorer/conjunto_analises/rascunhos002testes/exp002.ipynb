# %%
# Imports

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Import datasets

df_retail = pd.read_excel(r'C:\Users\JacyzinGuilherme(Bip\mentoria-bip\dados_editados\australia_retail.xlsx')
df_clima = pd.read_csv(r'C:\Users\JacyzinGuilherme(Bip\mentoria-bip\dados_editados\australia_clima_v3.csv')

# %%
# Verificando primeiras 5 linhas - df_retail

df_retail.head(5)
# Out:
#   tipo_negocio     loja_negocio localidade horario_abertura  \
# 0     Clothing      Fashion Hub  Melbourne         09:00:00
# 1    Bookstore        Book Nook   Brisbane         09:00:00
# 2    Bookstore        Book Nook   Adelaide         08:00:00
# 3    Bookstore        Book Nook  Melbourne         09:00:00
# 4    Furniture  Home Essentials     Sydney         07:00:00
#
#   horario_fechamento horario_maior_fluxo horario_pico_vendas  \
# 0           20:00:00            19:00:00            16:00:00
# 1           22:00:00            14:00:00            18:00:00
# 2           21:00:00            16:00:00            19:00:00
# 3           18:00:00            18:00:00            19:00:00
# 4           20:00:00            15:00:00            21:00:00
#
#   alocacao_funcionarios horario_pico_vendas_2  vendas_medias_diarias  \
# 0           Overstaffed              20:00:00                3520.77
# 1          Understaffed              17:00:00                2915.36
# 2           Overstaffed              18:00:00                1984.46
# 3           Overstaffed              19:00:00                 644.22
# 4          Understaffed              18:00:00                 620.63
#
#    vendas_medias_semanais             produtos_populares perfil_clientes  \
# 0                23527.26                T-shirts, Jeans    Young Adults
# 1                27744.20  Children's Books, Non-fiction           Teens
# 2                22411.88  Non-fiction, Children's Books           Teens
# 3                31314.84           Fiction, Non-fiction           Teens
# 4                27881.23                  Chairs, Sofas         Seniors
#
#   metodos_pagamento satisfacao_clientes lucratividade_loja  \
# 0       Credit Card                Good          Decreased
# 1       Credit Card                Good          Decreased
# 2       Credit Card                 Bad          Decreased
# 3    Digital Wallet                 Bad          Decreased
# 4              Cash                Good          Increased
#
#   satisfacao_funcionarios reclamacoes_trabalhistas
# 0            Dissatisfied                      Yes
# 1            Dissatisfied                      Yes
# 2               Satisfied                       No
# 3            Dissatisfied                      Yes
# 4               Satisfied                       No

# %%
# Tamanho de retail

df_retail.shape
# Out:
# (500, 18)

# %%
# Infos gerais df_retail

df_retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   tipo_negocio              500 non-null    object
#  1   loja_negocio              500 non-null    object
#  2   localidade                500 non-null    object
#  3   horario_abertura          500 non-null    object
#  4   horario_fechamento        500 non-null    object
#  5   horario_maior_fluxo       500 non-null    object
#  6   horario_pico_vendas       500 non-null    object
#  7   alocacao_funcionarios     500 non-null    object
#  8   horario_pico_vendas_2     500 non-null    object
#  9   vendas_medias_diarias     500 non-null    float64
#  10  vendas_medias_semanais    500 non-null    float64
#  11  produtos_populares        500 non-null    object
#  12  perfil_clientes           500 non-null    object
#  13  metodos_pagamento         500 non-null    object
#  14  satisfacao_clientes       500 non-null    object
#  15  lucratividade_loja        500 non-null    object
#  16  satisfacao_funcionarios   500 non-null    object
#  17  reclamacoes_trabalhistas  500 non-null    object
# dtypes: float64(2), object(16)
# memory usage: 70.4+ KB

# %%
# Verificando valores nulos de df_retail

df_retail.isna().sum()
# Out:
# tipo_negocio                0
# loja_negocio                0
# localidade                  0
# horario_abertura            0
# horario_fechamento          0
# horario_maior_fluxo         0
# horario_pico_vendas         0
# alocacao_funcionarios       0
# horario_pico_vendas_2       0
# vendas_medias_diarias       0
# vendas_medias_semanais      0
# produtos_populares          0
# perfil_clientes             0
# metodos_pagamento           0
# satisfacao_clientes         0
# lucratividade_loja          0
# satisfacao_funcionarios     0
# reclamacoes_trabalhistas    0
# dtype: int64

# %%
# Verificando primeiras 5 linhas - df_clima

df_clima.head(5)
# Out:
#          data localidade  temp_min  temp_max  chuva_mm  evaporacao  horas_sol  \
# 0  2010-10-08     Sydney      13.8      19.5       0.0         4.6        9.5
# 1  2010-10-11     Sydney      16.5      21.1       1.2         6.2        6.6
# 2  2010-10-12     Sydney      16.4      21.8       1.0         6.0        5.9
# 3  2010-10-13     Sydney      16.7      23.9       0.4         7.0        2.8
# 4  2010-10-14     Sydney      17.8      28.9       2.0         4.0       10.8
#
#   vento_rajada_direcao  vento_rajada_velocidade vento_direcao_9h  ...  \
# 0                  ESE                     35.0              NNE  ...
# 1                  ENE                     56.0               NE  ...
# 2                  NNE                     50.0              NNE  ...
# 3                  NNE                     39.0                W  ...
# 4                  NNW                     41.0              NNW  ...
#
#   cluster_temp_9h  cluster_temp_15h  cluster_umidade_9h  cluster_umidade_15h  \
# 0           ameno             ameno            tropical                ameno
# 1           ameno            quente               ameno                ameno
# 2           ameno            quente            tropical                ameno
# 3           ameno            quente            tropical                ameno
# 4          quente            quente               ameno                ameno
#
#    cluster_chuva_mm  cluster_rajada_vento     cluster_hora_sol  \
# 0              seco              moderado  muitas horas de sol
# 1              seco                 forte  médias horas de sol
# 2              seco                 forte  médias horas de sol
# 3              seco              moderado  poucas horas de sol
# 4              seco                 forte  muitas horas de sol
#
#    cluster_pressao_at_9h  cluster_pressao_at_15h      cluster_nuvem_9h
# 0                 normal                  normal  parcialmente nublado
# 1                 normal                  normal  parcialmente nublado
# 2                 normal                  normal  parcialmente nublado
# 3                 normal                  normal  parcialmente nublado
# 4                 normal                   baixa  parcialmente nublado
#
# [5 rows x 38 columns]

# %%
# Tamanho de df_clima

df_clima.shape
# Out:
# (13349, 38)

# %%
# Infos gerais df_retail

df_clima.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13349 entries, 0 to 13348
# Data columns (total 38 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   data                     13349 non-null  object
#  1   localidade               13349 non-null  object
#  2   temp_min                 13349 non-null  float64
#  3   temp_max                 13349 non-null  float64
#  4   chuva_mm                 13349 non-null  float64
#  5   evaporacao               13349 non-null  float64
#  6   horas_sol                13349 non-null  float64
#  7   vento_rajada_direcao     13349 non-null  object
#  8   vento_rajada_velocidade  13349 non-null  float64
#  9   vento_direcao_9h         13349 non-null  object
#  10  vento_direcao_15h        13349 non-null  object
#  11  vento_veloc_9h           13349 non-null  float64
#  12  vento_veloc_15h          13349 non-null  float64
#  13  umidade_9h               13349 non-null  float64
#  14  umidade_15h              13349 non-null  float64
#  15  pressao_9h               13349 non-null  float64
#  16  pressao_15h              13349 non-null  float64
#  17  nuvem_9h                 13349 non-null  float64
#  18  nuvem_15h                13349 non-null  float64
#  19  temp_9h                  13349 non-null  float64
#  20  temp_15h                 13349 non-null  float64
#  21  choveu_hoje              13349 non-null  object
#  22  chove_amanha             13349 non-null  object
#  23  ano                      13349 non-null  int64
#  24  mes                      13349 non-null  int64
#  25  dia                      13349 non-null  int64
#  26  cluster_temp_min         13349 non-null  object
#  27  cluster_temp_max         13349 non-null  object
#  28  cluster_temp_9h          13349 non-null  object
#  29  cluster_temp_15h         13349 non-null  object
#  30  cluster_umidade_9h       13349 non-null  object
#  31  cluster_umidade_15h      13349 non-null  object
#  32  cluster_chuva_mm         13349 non-null  object
#  33  cluster_rajada_vento     13349 non-null  object
#  34  cluster_hora_sol         13349 non-null  object
#  35  cluster_pressao_at_9h    13349 non-null  object
#  36  cluster_pressao_at_15h   13349 non-null  object
#  37  cluster_nuvem_9h         13349 non-null  object
# dtypes: float64(16), int64(3), object(19)
# memory usage: 3.9+ MB

# %%
# Verificando valores nulos de df_retail

df_clima.isna().sum()
# Out:
# data                       0
# localidade                 0
# temp_min                   0
# temp_max                   0
# chuva_mm                   0
# evaporacao                 0
# horas_sol                  0
# vento_rajada_direcao       0
# vento_rajada_velocidade    0
# vento_direcao_9h           0
# vento_direcao_15h          0
# vento_veloc_9h             0
# vento_veloc_15h            0
# umidade_9h                 0
# umidade_15h                0
# pressao_9h                 0
# pressao_15h                0
# nuvem_9h                   0
# nuvem_15h                  0
# temp_9h                    0
# temp_15h                   0
# choveu_hoje                0
# chove_amanha               0
# ano                        0
# mes                        0
# dia                        0
# cluster_temp_min           0
# cluster_temp_max           0
# cluster_temp_9h            0
# cluster_temp_15h           0
# cluster_umidade_9h         0
# cluster_umidade_15h        0
# cluster_chuva_mm           0
# cluster_rajada_vento       0
# cluster_hora_sol           0
# cluster_pressao_at_9h      0
# cluster_pressao_at_15h     0
# cluster_nuvem_9h           0
# dtype: int64

# %%
display(df_clima), display(df_retail)
# Out:
#              data localidade  temp_min  temp_max  chuva_mm  evaporacao  \
# 0      2010-10-08     Sydney      13.8      19.5       0.0         4.6
# 1      2010-10-11     Sydney      16.5      21.1       1.2         6.2
# 2      2010-10-12     Sydney      16.4      21.8       1.0         6.0
# 3      2010-10-13     Sydney      16.7      23.9       0.4         7.0
# 4      2010-10-14     Sydney      17.8      28.9       2.0         4.0
# ...           ...        ...       ...       ...       ...         ...
# 13344  2017-06-21      Perth      10.3      19.9       0.2         1.8
# 13345  2017-06-22      Perth      13.0      16.8      61.2         3.6
# 13346  2017-06-23      Perth      13.3      18.9       0.4         1.8
# 13347  2017-06-24      Perth      11.5      18.2       0.0         3.8
# 13348  2017-06-25      Perth       6.3      17.0       0.0         1.6
#
#        horas_sol vento_rajada_direcao  vento_rajada_velocidade  \
# 0            9.5                  ESE                     35.0
# 1            6.6                  ENE                     56.0
# 2            5.9                  NNE                     50.0
# 3            2.8                  NNE                     39.0
# 4           10.8                  NNW                     41.0
# ...          ...                  ...                      ...
# 13344        7.5                   NW                     37.0
# 13345        0.0                  SSW                     46.0
# 13346        6.5                   SE                     37.0
# 13347        9.3                   SE                     30.0
# 13348        7.9                    E                     26.0
#
#       vento_direcao_9h  ... cluster_temp_9h  cluster_temp_15h  \
# 0                  NNE  ...           ameno             ameno
# 1                   NE  ...           ameno            quente
# 2                  NNE  ...           ameno            quente
# 3                    W  ...           ameno            quente
# 4                  NNW  ...          quente            quente
# ...                ...  ...             ...               ...
# 13344              NNE  ...           ameno             ameno
# 13345                W  ...           ameno             ameno
# 13346               SE  ...           ameno             ameno
# 13347              ESE  ...           ameno             ameno
# 13348               SE  ...           ameno             ameno
#
#        cluster_umidade_9h  cluster_umidade_15h  cluster_chuva_mm  \
# 0                tropical                ameno              seco
# 1                   ameno                ameno              seco
# 2                tropical                ameno              seco
# 3                tropical                ameno              seco
# 4                   ameno                ameno              seco
# ...                   ...                  ...               ...
# 13344            tropical                ameno              seco
# 13345            tropical             tropical           extrema
# 13346            tropical                ameno              seco
# 13347               ameno                ameno              seco
# 13348            tropical                ameno              seco
#
#        cluster_rajada_vento     cluster_hora_sol  cluster_pressao_at_9h  \
# 0                  moderado  muitas horas de sol                 normal
# 1                     forte  médias horas de sol                 normal
# 2                     forte  médias horas de sol                 normal
# 3                  moderado  poucas horas de sol                 normal
# 4                     forte  muitas horas de sol                 normal
# ...                     ...                  ...                    ...
# 13344              moderado  médias horas de sol                 normal
# 13345                 forte  poucas horas de sol                  baixa
# 13346              moderado  médias horas de sol                   alta
# 13347              moderado  muitas horas de sol                   alta
# 13348              moderado  médias horas de sol                   alta
#
#        cluster_pressao_at_15h      cluster_nuvem_9h
# 0                      normal  parcialmente nublado
# 1                      normal  parcialmente nublado
# 2                      normal  parcialmente nublado
# 3                      normal  parcialmente nublado
# 4                       baixa  parcialmente nublado
# ...                       ...                   ...
# 13344                  normal  parcialmente nublado
# 13345                   baixa  parcialmente nublado
# 13346                    alta  parcialmente nublado
# 13347                    alta  parcialmente nublado
# 13348                    alta  parcialmente nublado
#
# [13349 rows x 38 columns]
#     tipo_negocio     loja_negocio localidade horario_abertura  \
# 0       Clothing      Fashion Hub  Melbourne         09:00:00
# 1      Bookstore        Book Nook   Brisbane         09:00:00
# 2      Bookstore        Book Nook   Adelaide         08:00:00
# 3      Bookstore        Book Nook  Melbourne         09:00:00
# 4      Furniture  Home Essentials     Sydney         07:00:00
# ..           ...              ...        ...              ...
# 495     Clothing      Fashion Hub  Melbourne         07:00:00
# 496      Grocery    Green Grocers     Sydney         08:00:00
# 497     Clothing      Fashion Hub      Perth         07:00:00
# 498     Clothing      Fashion Hub     Sydney         08:00:00
# 499    Bookstore        Book Nook     Sydney         10:00:00
#
#     horario_fechamento horario_maior_fluxo horario_pico_vendas  \
# 0             20:00:00            19:00:00            16:00:00
# 1             22:00:00            14:00:00            18:00:00
# 2             21:00:00            16:00:00            19:00:00
# 3             18:00:00            18:00:00            19:00:00
# 4             20:00:00            15:00:00            21:00:00
# ..                 ...                 ...                 ...
# 495           20:00:00            18:00:00            17:00:00
# 496           18:00:00            11:00:00            17:00:00
# 497           21:00:00            12:00:00            20:00:00
# 498           19:00:00            20:00:00            17:00:00
# 499           21:00:00            13:00:00            21:00:00
#
#     alocacao_funcionarios horario_pico_vendas_2  vendas_medias_diarias  \
# 0             Overstaffed              20:00:00                3520.77
# 1            Understaffed              17:00:00                2915.36
# 2             Overstaffed              18:00:00                1984.46
# 3             Overstaffed              19:00:00                 644.22
# 4            Understaffed              18:00:00                 620.63
# ..                    ...                   ...                    ...
# 495           Overstaffed              20:00:00                 507.56
# 496          Understaffed              17:00:00                3618.03
# 497           Overstaffed              20:00:00                1569.51
# 498          Understaffed              19:00:00                1411.71
# 499           Overstaffed              17:00:00                2615.05
#
#      vendas_medias_semanais             produtos_populares perfil_clientes  \
# 0                  23527.26                T-shirts, Jeans    Young Adults
# 1                  27744.20  Children's Books, Non-fiction           Teens
# 2                  22411.88  Non-fiction, Children's Books           Teens
# 3                  31314.84           Fiction, Non-fiction           Teens
# 4                  27881.23                  Chairs, Sofas         Seniors
# ..                      ...                            ...             ...
# 495                 5081.61                 Dresses, Jeans    Young Adults
# 496                29709.42     Vegetables, Dairy Products        Families
# 497                 9908.53                 Dresses, Jeans    Young Adults
# 498                33851.77                T-shirts, Jeans    Young Adults
# 499                31314.89      Fiction, Children's Books           Teens
#
#     metodos_pagamento satisfacao_clientes lucratividade_loja  \
# 0         Credit Card                Good          Decreased
# 1         Credit Card                Good          Decreased
# 2         Credit Card                 Bad          Decreased
# 3      Digital Wallet                 Bad          Decreased
# 4                Cash                Good          Increased
# ..                ...                 ...                ...
# 495    Digital Wallet                Good          Increased
# 496        Debit Card                 Bad          Increased
# 497    Digital Wallet                Good          Increased
# 498       Credit Card                Good          Increased
# 499    Digital Wallet                Good          Increased
#
#     satisfacao_funcionarios reclamacoes_trabalhistas
# 0              Dissatisfied                      Yes
# 1              Dissatisfied                      Yes
# 2                 Satisfied                       No
# 3              Dissatisfied                      Yes
# 4                 Satisfied                       No
# ..                      ...                      ...
# 495               Satisfied                       No
# 496               Satisfied                      Yes
# 497            Dissatisfied                       No
# 498            Dissatisfied                      Yes
# 499            Dissatisfied                      Yes
#
# [500 rows x 18 columns]
# (None, None)

# %%
# Cidades / Localidades com maior resultado de venda média diária

vendas_por_cidade = df_retail.groupby('localidade')['vendas_medias_diarias'].mean().rename('vendas_medias_diarias')
display(vendas_por_cidade.round(2).sort_values(ascending=False))
# Out:
# localidade
# Sydney       3068.43
# Brisbane     2898.42
# Melbourne    2687.14
# Adelaide     2505.73
# Perth        2459.98
# Name: vendas_medias_diarias, dtype: float64

# %%
# Gráfico

# Ordenação de dados

vendas_por_cidade_ord = vendas_por_cidade.sort_values(ascending=False).reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(data=vendas_por_cidade_ord, x='vendas_medias_diarias', y='localidade', color='darkblue')

plt.title('Vendas Médias Diárias por Cidade')
plt.xlabel('Vendas Médias Diárias')
plt.ylabel('Cidade')

plt.tight_layout()
plt.show()

# %%
# Tipo de Negócio e Loja - resultados de vendas

vendas_tipo_negocio = df_retail.groupby(['tipo_negocio', 'loja_negocio'], as_index=False).agg(vendas_medias_diarias = ('vendas_medias_diarias', 'mean'), vendas_minimas=('vendas_medias_diarias', 'min'), vendas_maximas=('vendas_medias_diarias', 'max')).sort_values(by='vendas_medias_diarias', ascending=False)
display(vendas_tipo_negocio.round(2))
# Out:
#   tipo_negocio     loja_negocio  vendas_medias_diarias  vendas_minimas  \
# 2  Electronics       Tech Store                3179.99          753.05
# 4      Grocery    Green Grocers                2942.67         1646.03
# 1     Clothing      Fashion Hub                2673.30          494.54
# 3    Furniture  Home Essentials                2584.94          595.51
# 0    Bookstore        Book Nook                2470.30          567.18
#
#    vendas_maximas
# 2         5199.46
# 4         4397.82
# 1         4611.38
# 3         5103.27
# 0         4045.92

# %%
# Gráfico

# selecionar top 10 lojas por média
top10 = vendas_tipo_negocio.head(10).reset_index(drop=True)

plt.figure(figsize=(12, 6))

for i, row in top10.iterrows():
    plt.plot(
        [row['vendas_minimas'], row['vendas_maximas']],
        [i, i],
        color='gray',
        alpha=0.7
    )
    plt.scatter(
        row['vendas_medias_diarias'],
        i,
        color='black',
        zorder=3
    )

plt.yticks(
    range(len(top10)),
    top10['tipo_negocio'] + ' | ' + top10['loja_negocio']
)

plt.xlabel('Vendas Diárias')
plt.title('Faixa de Vendas Diárias por Tipo de Negócio e Loja (Top 10)')
plt.grid(axis='x', linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()

# %%
# Tipo de Negócio, Loja e Localidade - resultado de vendas

vendas_tipo_negocio = df_retail.groupby(['tipo_negocio', 'loja_negocio', 'localidade'], as_index=False).agg(vendas_medias_diarias = ('vendas_medias_diarias', 'mean'), vendas_minimas=('vendas_medias_diarias', 'min'), vendas_maximas=('vendas_medias_diarias', 'max')).sort_values(by='vendas_medias_diarias', ascending=False)
display(vendas_tipo_negocio.round(2))
# Out:
#    tipo_negocio     loja_negocio localidade  vendas_medias_diarias  \
# 17    Furniture  Home Essentials  Melbourne                4748.96
# 11  Electronics       Tech Store   Brisbane                4283.00
# 14  Electronics       Tech Store     Sydney                4236.84
# 22      Grocery    Green Grocers     Sydney                4057.80
# 12  Electronics       Tech Store  Melbourne                3360.96
# 13  Electronics       Tech Store      Perth                3218.90
# 4     Bookstore        Book Nook     Sydney                3209.25
# 5      Clothing      Fashion Hub   Adelaide                3192.51
# 20      Grocery    Green Grocers   Brisbane                2958.54
# 15    Furniture  Home Essentials   Adelaide                2837.37
# 1     Bookstore        Book Nook   Brisbane                2756.30
# 7      Clothing      Fashion Hub  Melbourne                2745.07
# 9      Clothing      Fashion Hub     Sydney                2715.80
# 0     Bookstore        Book Nook   Adelaide                2581.13
# 6      Clothing      Fashion Hub   Brisbane                2565.55
# 19    Furniture  Home Essentials     Sydney                2519.10
# 8      Clothing      Fashion Hub      Perth                2246.65
# 21      Grocery    Green Grocers  Melbourne                1795.81
# 3     Bookstore        Book Nook      Perth                1730.27
# 2     Bookstore        Book Nook  Melbourne                1649.14
# 10  Electronics       Tech Store   Adelaide                1640.84
# 18    Furniture  Home Essentials      Perth                1552.95
# 16    Furniture  Home Essentials   Brisbane                 958.99
#
#     vendas_minimas  vendas_maximas
# 17         4431.54         5103.27
# 11         3636.12         4957.99
# 14         3292.47         5199.46
# 22         3618.03         4397.82
# 12         3100.30         3756.60
# 13         2107.05         4093.49
# 4          2367.51         4011.80
# 5          1959.25         4574.39
# 20         2259.06         3916.35
# 15          921.69         4093.87
# 1          2334.61         3206.32
# 7           494.54         3960.08
# 9          1216.79         4611.38
# 0          1662.90         4045.92
# 6          2275.65         2813.12
# 19          595.51         4340.89
# 8          1569.51         3364.60
# 21         1646.03         1909.69
# 3          1553.78         1885.82
# 2           567.18         2846.88
# 10          753.05         2531.00
# 18         1401.10         1684.10
# 16          885.57         1024.01

# %%
# Gráfico

top10 = vendas_tipo_negocio.head(15).copy()
top10['grupo'] = top10['tipo_negocio'] + ' | ' + top10['loja_negocio'] + ' | ' + top10['localidade']

plt.figure(figsize=(12, 7))
sns.barplot(data=top10, x='vendas_medias_diarias', y='grupo', color='darkblue')

plt.title('Top 10: Média de Vendas Diárias por Tipo, Loja e Localidade')
plt.xlabel('Vendas Médias Diárias')
plt.ylabel('Tipo | Loja | Localidade')
plt.tight_layout()
plt.show()

# %%
# Loja - Negócio com maior resultado de venda média diária

vendas_loja = df_retail.groupby('loja_negocio')['vendas_medias_diarias'].mean().rename('vendas_medias_diarias')
display(vendas_loja.round(2).sort_values(ascending=False))
# Out:
# loja_negocio
# Tech Store         3179.99
# Green Grocers      2942.67
# Fashion Hub        2673.30
# Home Essentials    2584.94
# Book Nook          2470.30
# Name: vendas_medias_diarias, dtype: float64

# %%
# Gráfico

vendas_loja = df_retail.groupby('loja_negocio')['vendas_medias_diarias'].mean()
vendas_loja.name = 'vendas_medias_diarias'

vendas_loja_ord = vendas_loja.sort_values(ascending=False).reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(data=vendas_loja_ord, x='vendas_medias_diarias', y='loja_negocio', color='darkred')

plt.title('Vendas Médias Diárias por Loja')
plt.xlabel('Vendas Médias Diárias')
plt.ylabel('Loja')
plt.tight_layout()
plt.show()

# %%
# Vendas médias diárias por produto e por localidade

var_produto_localidade = df_retail.groupby(['localidade', 'produtos_populares'], as_index=False).agg(vendas_medias_diarias = ('vendas_medias_diarias', 'mean'), vendas_minimas=('vendas_medias_diarias', 'min'), vendas_maximas=('vendas_medias_diarias', 'max')).sort_values(by='vendas_medias_diarias', ascending=False)
display(var_produto_localidade.round(2))
# Out:
#    localidade             produtos_populares  vendas_medias_diarias  \
# 36     Sydney        Headphones, Smartphones                4815.48
# 24  Melbourne                 Tables, Chairs                4748.96
# 15   Brisbane            Headphones, Laptops                4568.67
# 38     Sydney                Jeans, T-shirts                4239.51
# 8    Adelaide                T-shirts, Jeans                4232.42
# 43     Sydney     Vegetables, Dairy Products                4057.80
# 17   Brisbane            Laptops, Headphones                3997.33
# 0    Adelaide                  Chairs, Sofas                3833.88
# 23  Melbourne                T-shirts, Jeans                3738.28
# 39     Sydney           Non-fiction, Fiction                3730.35
# 9    Adelaide                  Tables, Sofas                3682.23
# 2    Adelaide  Children's Books, Non-fiction                3670.16
# 40     Sydney        Smartphones, Headphones                3658.19
# 31      Perth           Laptops, Smartphones                3548.38
# 14   Brisbane             Fruits, Vegetables                3498.79
# 37     Sydney                 Jeans, Dresses                3370.71
# 21  Melbourne            Headphones, Laptops                3360.96
# 22  Melbourne                 Jeans, Dresses                3354.67
# 27      Perth              Dresses, T-shirts                3147.83
# 29      Perth            Headphones, Laptops                3054.16
# 10   Brisbane  Children's Books, Non-fiction                2947.65
# 35     Sydney      Fiction, Children's Books                2688.16
# 33     Sydney                  Chairs, Sofas                2655.92
# 16   Brisbane                Jeans, T-shirts                2650.75
# 12   Brisbane      Fiction, Children's Books                2564.94
# 11   Brisbane              Dresses, T-shirts                2480.36
# 13   Brisbane         Fruits, Dairy Products                2418.29
# 4    Adelaide            Headphones, Laptops                2318.89
# 3    Adelaide      Fiction, Children's Books                2217.30
# 7    Adelaide              T-shirts, Dresses                2152.60
# 42     Sydney                 Tables, Chairs                2108.62
# 34     Sydney                 Dresses, Jeans                1982.38
# 30      Perth                 Jeans, Dresses                1896.66
# 6    Adelaide  Non-fiction, Children's Books                1855.94
# 25  Melbourne     Vegetables, Dairy Products                1795.81
# 28      Perth           Fiction, Non-fiction                1730.27
# 26      Perth                 Dresses, Jeans                1695.45
# 20  Melbourne           Fiction, Non-fiction                1649.14
# 32      Perth                  Sofas, Chairs                1552.95
# 5    Adelaide        Headphones, Smartphones                1301.81
# 41     Sydney                T-shirts, Jeans                1270.59
# 1    Adelaide                 Chairs, Tables                 995.99
# 18   Brisbane                  Sofas, Chairs                 958.99
# 19  Melbourne                 Dresses, Jeans                 532.67
#
#     vendas_minimas  vendas_maximas
# 36         4395.77         5199.46
# 24         4431.54         5103.27
# 15         4201.80         4957.99
# 38         4079.83         4611.38
# 8          3861.50         4574.39
# 43         3618.03         4397.82
# 17         3636.12         4380.72
# 0          3519.04         4093.87
# 23         3520.77         3960.08
# 39         3458.06         4011.80
# 9          3369.75         3935.76
# 2          3376.28         4045.92
# 40         3292.47         3902.58
# 31         3264.17         3760.94
# 14         3281.77         3916.35
# 37         3034.59         3675.48
# 21         3100.30         3756.60
# 22         3046.26         3590.35
# 27         2835.30         3364.60
# 29         2107.05         4093.49
# 10         2709.91         3206.32
# 35         2367.51         2853.72
# 33          595.51         4340.89
# 16         2462.56         2813.12
# 12         2334.61         2829.48
# 11         2275.65         2671.32
# 13         2259.06         2592.98
# 4          2184.51         2531.00
# 3          1997.73         2420.05
# 7          1959.25         2351.58
# 42         1902.62         2260.98
# 34         1855.08         2197.73
# 30         1745.87         2076.49
# 6          1662.90         1984.46
# 25         1646.03         1909.69
# 28         1553.78         1885.82
# 26         1569.51         1835.54
# 20          567.18         2846.88
# 32         1401.10         1684.10
# 5           753.05         1826.49
# 41         1216.79         1411.71
# 1           921.69         1062.29
# 18          885.57         1024.01
# 19          494.54          576.77

# %%
# Gráfico

# Top 5 produtos por localidade
top_produtos = (var_produto_localidade.groupby('localidade', group_keys=False).head(5))

plt.figure(figsize=(12, 6))
sns.barplot(data=top_produtos, x='vendas_medias_diarias', y='produtos_populares', hue='localidade')

plt.title('Top Produtos por Localidade (Média de Vendas Diárias)')
plt.xlabel('Vendas Médias Diárias')
plt.ylabel('Produto')
plt.tight_layout()
plt.show()

# %%
# Vendas médias diárias por produto e perfil de público

vendas_perfilCliente_localidade = df_retail.groupby(['localidade', 'perfil_clientes'], as_index=False).agg(vendas_medias_diarias = ('vendas_medias_diarias', 'mean'), vendas_minimas=('vendas_medias_diarias', 'min'), vendas_maximas=('vendas_medias_diarias', 'max')).sort_values(by='vendas_medias_diarias', ascending=False)
display(vendas_perfilCliente_localidade.round(2))
# Out:
#    localidade perfil_clientes  vendas_medias_diarias  vendas_minimas  \
# 11  Melbourne         Seniors                4748.96         4431.54
# 5    Brisbane   Professionals                4283.00         3636.12
# 19     Sydney   Professionals                4236.84         3292.47
# 18     Sydney        Families                4057.80         3618.03
# 10  Melbourne   Professionals                3360.96         3100.30
# 14      Perth   Professionals                3218.90         2107.05
# 21     Sydney           Teens                3209.25         2367.51
# 3    Adelaide    Young Adults                3192.51         1959.25
# 4    Brisbane        Families                2958.54         2259.06
# 1    Adelaide         Seniors                2837.37          921.69
# 7    Brisbane           Teens                2756.30         2334.61
# 13  Melbourne    Young Adults                2745.07          494.54
# 22     Sydney    Young Adults                2715.80         1216.79
# 2    Adelaide           Teens                2581.13         1662.90
# 8    Brisbane    Young Adults                2565.55         2275.65
# 20     Sydney         Seniors                2519.10          595.51
# 17      Perth    Young Adults                2246.65         1569.51
# 9   Melbourne        Families                1795.81         1646.03
# 16      Perth           Teens                1730.27         1553.78
# 12  Melbourne           Teens                1649.14          567.18
# 0    Adelaide   Professionals                1640.84          753.05
# 15      Perth         Seniors                1552.95         1401.10
# 6    Brisbane         Seniors                 958.99          885.57
#
#     vendas_maximas
# 11         5103.27
# 5          4957.99
# 19         5199.46
# 18         4397.82
# 10         3756.60
# 14         4093.49
# 21         4011.80
# 3          4574.39
# 4          3916.35
# 1          4093.87
# 7          3206.32
# 13         3960.08
# 22         4611.38
# 2          4045.92
# 8          2813.12
# 20         4340.89
# 17         3364.60
# 9          1909.69
# 16         1885.82
# 12         2846.88
# 0          2531.00
# 15         1684.10
# 6          1024.01

# %%
# Gráfico

# pivot: linhas = localidade, colunas = perfil, valores = média
pivot_perfil = vendas_perfilCliente_localidade.pivot_table(
    index='localidade',
    columns='perfil_clientes',
    values='vendas_medias_diarias',
    aggfunc='mean'
)

plt.figure(figsize=(12, 6))
sns.heatmap(
    pivot_perfil,
    annot=True,
    fmt='.1f'
)

plt.title('Média de Vendas Diárias por Localidade e Perfil de Clientes')
plt.xlabel('Perfil de Clientes')
plt.ylabel('Localidade')
plt.tight_layout()
plt.show()

# %%
top3_perfis = (vendas_perfilCliente_localidade.groupby('localidade', group_keys=False).head(3).copy())

plt.figure(figsize=(12, 7))
sns.barplot(data=top3_perfis, x='vendas_medias_diarias', y='perfil_clientes', hue='localidade')

plt.title('Top 3 Perfis por Localidade (Média de Vendas Diárias)')
plt.xlabel('Vendas Médias Diárias')
plt.ylabel('Perfil de Clientes')
plt.tight_layout()
plt.show()

# %%
# Perfil de clientes por produto vs vendas 

vendas_perfilCliente_produtos = df_retail.groupby(['perfil_clientes', 'produtos_populares'], as_index=False).agg(vendas_medias_diarias = ('vendas_medias_diarias', 'mean'), vendas_minimas=('vendas_medias_diarias', 'min'), vendas_maximas=('vendas_medias_diarias', 'max')).sort_values(by='vendas_medias_diarias', ascending=False)
display(vendas_perfilCliente_produtos.round(2))
# Out:
#    perfil_clientes             produtos_populares  vendas_medias_diarias  \
# 5    Professionals            Laptops, Headphones                3997.33
# 17           Teens           Non-fiction, Fiction                3730.35
# 12         Seniors                  Tables, Sofas                3682.23
# 7    Professionals        Smartphones, Headphones                3658.19
# 6    Professionals           Laptops, Smartphones                3548.38
# 1         Families             Fruits, Vegetables                3498.79
# 21    Young Adults                Jeans, T-shirts                3445.13
# 11         Seniors                 Tables, Chairs                3428.79
# 13           Teens  Children's Books, Non-fiction                3308.91
# 3    Professionals            Headphones, Laptops                3271.37
# 23    Young Adults                T-shirts, Jeans                3080.43
# 20    Young Adults                 Jeans, Dresses                2994.18
# 8          Seniors                  Chairs, Sofas                2950.41
# 2         Families     Vegetables, Dairy Products                2926.81
# 19    Young Adults              Dresses, T-shirts                2814.10
# 14           Teens      Fiction, Children's Books                2490.13
# 4    Professionals        Headphones, Smartphones                2473.04
# 0         Families         Fruits, Dairy Products                2418.29
# 22    Young Adults              T-shirts, Dresses                2152.60
# 16           Teens  Non-fiction, Children's Books                1855.94
# 15           Teens           Fiction, Non-fiction                1676.18
# 18    Young Adults                 Dresses, Jeans                1403.50
# 10         Seniors                  Sofas, Chairs                1255.97
# 9          Seniors                 Chairs, Tables                 995.99
#
#     vendas_minimas  vendas_maximas
# 5          3636.12         4380.72
# 17         3458.06         4011.80
# 12         3369.75         3935.76
# 7          3292.47         3902.58
# 6          3264.17         3760.94
# 1          3281.77         3916.35
# 21         2462.56         4611.38
# 11         1902.62         5103.27
# 13         2709.91         4045.92
# 3          2107.05         4957.99
# 23         1216.79         4574.39
# 20         1745.87         3675.48
# 8           595.51         4340.89
# 2          1646.03         4397.82
# 19         2275.65         3364.60
# 14         1997.73         2853.72
# 4           753.05         5199.46
# 0          2259.06         2592.98
# 22         1959.25         2351.58
# 16         1662.90         1984.46
# 15          567.18         2846.88
# 18          494.54         2197.73
# 10          885.57         1684.10
# 9           921.69         1062.29

# %%
# Gráfico

# Selecionar Top 3 produtos por perfil
top_produtos_perfil = (vendas_perfilCliente_produtos.groupby('perfil_clientes', group_keys=False).head(3).copy())

plt.figure(figsize=(12, 7))
sns.barplot(data=top_produtos_perfil, x='vendas_medias_diarias', y='produtos_populares', hue='perfil_clientes')

plt.title('Top 3 Produtos por Perfil de Cliente (Média de Vendas Diárias)')
plt.xlabel('Vendas Médias Diárias')
plt.ylabel('Produto')
plt.legend(title='Perfil de Cliente')
plt.tight_layout()
plt.show()

# %%
# Gráfico B

g = sns.catplot(data=top_produtos_perfil, x='vendas_medias_diarias', y='produtos_populares', col='perfil_clientes', kind='bar', col_wrap=3, height=4, sharex=False)

g.set_titles('{col_name}')
g.set_axis_labels('Vendas Médias Diárias', 'Produto')
g.fig.suptitle('Top Produtos por Perfil de Cliente', y=1.05)
plt.show()

# %%
# Verificando valores únicos de df_clima

df_clima['cluster_chuva_mm'].unique()
# Out:
# array(['seco', 'moderada', 'extrema', 'forte'], dtype=object)

# %%
# Cidades com maior porcentagem de dias secos, têm lojas com maior venda diária?


# Calcular total de dias por localidade
total_dias = (df_clima.groupby('localidade').size().rename('total_dias'))

# Dias secos por localidade // cidade
dias_secos = (df_clima[df_clima['cluster_chuva_mm'] == 'seco'].groupby('localidade').size().rename('dias_secos'))

# Merge // join dos dados - juntando total + dias secos
clima_seco = total_dias.to_frame().join(dias_secos, how='left')
clima_seco['dias_secos'] = clima_seco['dias_secos'].fillna(0)

# % dias secos
clima_seco['porcentagem_dias_secos'] = clima_seco['dias_secos'] / clima_seco['total_dias']


# Usando retail por localidade
vendas_por_cidade = df_retail.groupby('localidade')['vendas_medias_diarias'].mean().rename('vendas_medias_diarias_por_loja')

# Clima e Vendas
analise1 = clima_seco.join(vendas_por_cidade, how='left').round(2)
display(analise1)
# Out:
#             total_dias  dias_secos  porcentagem_dias_secos  \
# localidade
# Adelaide          2746        2270                    0.83
# Brisbane          3029        2484                    0.82
# Melbourne         2240        1821                    0.81
# Perth             3049        2541                    0.83
# Sydney            2285        1774                    0.78
#
#             vendas_medias_diarias_por_loja
# localidade
# Adelaide                           2505.73
# Brisbane                           2898.42
# Melbourne                          2687.14
# Perth                              2459.98
# Sydney                             3068.43

# %%
# Gráfico

# garantir dataframe com colunas
plot_df = analise1.reset_index()  # traz 'localidade' como coluna

plt.figure(figsize=(8, 6))
sns.regplot(data=plot_df, x='porcentagem_dias_secos', y='vendas_medias_diarias_por_loja')

plt.title('% de Dias Secos vs Média de Vendas Diárias (por Localidade)')
plt.xlabel('Porcentagem de dias secos')
plt.ylabel('Média de vendas diárias')

# rótulos das cidades (útil porque são poucos pontos)
for _, row in plot_df.iterrows():
    plt.text(row['porcentagem_dias_secos'], row['vendas_medias_diarias_por_loja'], str(row['localidade']), fontsize=9, ha='left', va='bottom')

plt.tight_layout()
plt.show()

# %%
# Cidades com maior porcentagem de dias secos, têm lojas com maior venda diária?


# Calcular total de dias por localidade
total_dias = (df_clima.groupby('localidade').size().rename('total_dias'))

# Dias secos por localidade // cidade
dias_moderados = (df_clima[df_clima['cluster_chuva_mm'] == 'moderada'].groupby('localidade').size().rename('dias_moderados'))

# Merge // join dos dados - juntando total + dias secos
clima_moderado = total_dias.to_frame().join(dias_moderados, how='left')
clima_moderado['dias_moderados'] = clima_moderado['dias_moderados'].fillna(0)

# % dias secos
clima_moderado['porcentagem_dias_moderados'] = clima_moderado['dias_moderados'] / clima_moderado['total_dias'] * 100

# Usando retail por localidade
vendas_por_cidade = df_retail.groupby('localidade')['vendas_medias_diarias'].mean().rename('vendas_medias_diarias_por_loja')

# Clima e Vendas
analise2 = clima_moderado.join(vendas_por_cidade, how='left').round(2)
display(analise2)
# Out:
#             total_dias  dias_moderados  porcentagem_dias_moderados  \
# localidade
# Adelaide          2746             350                       12.75
# Brisbane          3029             309                       10.20
# Melbourne         2240             306                       13.66
# Perth             3049             323                       10.59
# Sydney            2285             292                       12.78
#
#             vendas_medias_diarias_por_loja
# localidade
# Adelaide                           2505.73
# Brisbane                           2898.42
# Melbourne                          2687.14
# Perth                              2459.98
# Sydney                             3068.43

# %%
# Cidades com maior porcentagem de dias secos, têm lojas com maior venda diária?


# Calcular total de dias por localidade
total_dias = (df_clima.groupby('localidade').size().rename('total_dias'))

# Dias secos por localidade // cidade
dias_fortes = (df_clima[df_clima['cluster_chuva_mm'] == 'Forte'].groupby('localidade').size().rename('dias_fortes'))

# Merge // join dos dados - juntando total + dias secos
clima_forte = total_dias.to_frame().join(dias_fortes, how='left')
clima_forte['dias_fortes'] = clima_forte['dias_fortes'].fillna(0)

# % dias secos
clima_forte['porcentagem_dias_fortes'] = clima_forte['dias_fortes'] / clima_forte['total_dias'] * 100


# Usando retail por localidade
vendas_por_cidade = df_retail.groupby('localidade')['vendas_medias_diarias'].mean().rename('vendas_medias_diarias_por_loja')

# Clima e Vendas
analise3 = clima_forte.join(vendas_por_cidade, how='left').round(2)
display(analise3)
# Out:
#             total_dias  dias_fortes  porcentagem_dias_fortes  \
# localidade
# Adelaide          2746          0.0                      0.0
# Brisbane          3029          0.0                      0.0
# Melbourne         2240          0.0                      0.0
# Perth             3049          0.0                      0.0
# Sydney            2285          0.0                      0.0
#
#             vendas_medias_diarias_por_loja
# localidade
# Adelaide                           2505.73
# Brisbane                           2898.42
# Melbourne                          2687.14
# Perth                              2459.98
# Sydney                             3068.43

# %%
# Cidades com maior porcentagem de dias secos, têm lojas com maior venda diária?


# Calcular total de dias por localidade
total_dias = (df_clima.groupby('localidade').size().rename('total_dias'))

# Dias secos por localidade // cidade
dias_extremos = (df_clima[df_clima['cluster_chuva_mm'] == 'extrema'].groupby('localidade').size().rename('dias_extremas'))

# Merge // join dos dados - juntando total + dias secos
clima_extremo = total_dias.to_frame().join(dias_extremos, how='left')
clima_extremo['dias_extremas'] = clima_extremo['dias_extremas'].fillna(0)

# % dias secos
clima_extremo['porcentagem_dias_extremos'] = clima_extremo['dias_extremas'] / clima_forte['total_dias'] * 100


# Usando retail por localidade
vendas_por_cidade = df_retail.groupby('localidade')['vendas_medias_diarias'].mean().rename('vendas_medias_diarias_por_loja')

# Clima e Vendas
analise4 = clima_extremo.join(vendas_por_cidade, how='left').round(2)
display(analise4)

"""
analise4_cor_teste = analise4.corr().round(2)
display(analise4_cor_teste)
"""
# Out:
#             total_dias  dias_extremas  porcentagem_dias_extremos  \
# localidade
# Adelaide          2746             13                       0.47
# Brisbane          3029             74                       2.44
# Melbourne         2240             15                       0.67
# Perth             3049             26                       0.85
# Sydney            2285             64                       2.80
#
#             vendas_medias_diarias_por_loja
# localidade
# Adelaide                           2505.73
# Brisbane                           2898.42
# Melbourne                          2687.14
# Perth                              2459.98
# Sydney                             3068.43
# '\nanalise4_cor_teste = analise4.corr().round(2)\ndisplay(analise4_cor_teste)\n'

# %%
"""df_clima['cluster_chuva_mm'].value_counts(dropna=False),
plot_df[['%_dias_chuva_forte']].isna().sum()
plot_df[['%_dias_chuva_forte']].describe()"""
# Out:
# "df_clima['cluster_chuva_mm'].value_counts(dropna=False),\nplot_df[['%_dias_chuva_forte']].isna().sum()\nplot_df[['%_dias_chuva_forte']].describe()"

# %%
# Chuva vs vendas médias diárias - Existe influencia?

# Normalizando cabeçalho coluna
#df_clima['cluster_chuva_mm'] = df_clima['cluster_chuva_mm'].astype(str).str.strip().str.lower()

# Calcular total de dias por localidade
total_dias = (df_clima.groupby('localidade').size().rename('total_dias'))

# Chuvas por localidade // cidade
dias_sem_chuva = (df_clima[df_clima['cluster_chuva_mm'] == 'seco'].groupby('localidade').size().rename('dias_sem_chuva'))
dias_chuva_moderada = (df_clima[df_clima['cluster_chuva_mm'] == 'moderada'].groupby('localidade').size().rename('dias_chuva_moderada'))
dias_chuva_forte = (df_clima[df_clima['cluster_chuva_mm'] == 'forte'].groupby('localidade').size().rename('dias_chuva_forte'))
dias_chuva_extrema = (df_clima[df_clima['cluster_chuva_mm'] == 'extrema'].groupby('localidade').size().rename('dias_chuva_extrema'))

# Merge // join dos dados
dias_chuva = [dias_sem_chuva, dias_chuva_moderada, dias_chuva_forte, dias_chuva_extrema]
clima_analise = total_dias.to_frame().join(dias_chuva, how='left')

# Tratando possíveis NaN
#dias_chuva[clima_analise] = dias_chuva[dias_sem_chuva, dias_chuva_moderada, dias_chuva_forte, dias_chuva_extrema].fillna(0)

# Porcentagem chuva dias
clima_analise['%_dias_sem_chuva'] = (clima_analise['dias_sem_chuva'] / clima_analise['total_dias'] * 100)
clima_analise['%_dias_chuva_moderada'] = (clima_analise['dias_chuva_moderada'] / clima_analise['total_dias'] * 100)
clima_analise['%_dias_chuva_forte'] = (clima_analise['dias_chuva_forte'] / clima_analise['total_dias'] * 100)
clima_analise['%_dias_chuva_extrema'] = (clima_analise['dias_chuva_extrema'] / clima_analise['total_dias'] * 100)

# Agrupando vendas médias diárias por cidade
vendas_por_cidade = (df_retail.groupby('localidade')['vendas_medias_diarias'].mean().rename('vendas_medias_diarias_por_loja'))

# Merge // join dos dados de retail e clima
analise_final_chuva_vendas_diarias = clima_analise.join(vendas_por_cidade, how='left')

# Imprime
display(analise_final_chuva_vendas_diarias.round(2).sort_values(by='vendas_medias_diarias_por_loja', ascending=False))
# Out:
#             total_dias  dias_sem_chuva  dias_chuva_moderada  dias_chuva_forte  \
# localidade
# Sydney            2285            1774                  292               155
# Brisbane          3029            2484                  309               162
# Melbourne         2240            1821                  306                98
# Adelaide          2746            2270                  350               113
# Perth             3049            2541                  323               159
#
#             dias_chuva_extrema  %_dias_sem_chuva  %_dias_chuva_moderada  \
# localidade
# Sydney                      64             77.64                  12.78
# Brisbane                    74             82.01                  10.20
# Melbourne                   15             81.29                  13.66
# Adelaide                    13             82.67                  12.75
# Perth                       26             83.34                  10.59
#
#             %_dias_chuva_forte  %_dias_chuva_extrema  \
# localidade
# Sydney                    6.78                  2.80
# Brisbane                  5.35                  2.44
# Melbourne                 4.38                  0.67
# Adelaide                  4.12                  0.47
# Perth                     5.21                  0.85
#
#             vendas_medias_diarias_por_loja
# localidade
# Sydney                             3068.43
# Brisbane                           2898.42
# Melbourne                          2687.14
# Adelaide                           2505.73
# Perth                              2459.98

# %%
# Gráfico

plot_df = analise_final_chuva_vendas_diarias.reset_index()

fig, axes = plt.subplots(2, 2, figsize=(14, 10))
axes = axes.flatten()

pares = [
    ('%_dias_sem_chuva', 'Sem chuva (seco)'),
    ('%_dias_chuva_moderada', 'Chuva moderada'),
    ('%_dias_chuva_forte', 'Chuva forte'),
    ('%_dias_chuva_extrema', 'Chuva extrema'),
]

for ax, (col, titulo) in zip(axes, pares):
    sns.regplot(data=plot_df, x=col, y='vendas_medias_diarias_por_loja', ax=ax)

    ax.set_title(titulo)
    ax.set_xlabel('% de dias')
    ax.set_ylabel('Média de vendas diárias')

    # rótulos das cidades (como são poucos pontos, vale a pena)
    for _, row in plot_df.iterrows():
        ax.text(row[col], row['vendas_medias_diarias_por_loja'], str(row['localidade']), fontsize=9, ha='left', va='bottom')

plt.suptitle('Influência da Chuva na Média de Vendas Diárias por Localidade', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# Separando números de porcentagem
analise_final_chuva_vendas_diarias_num = analise_final_chuva_vendas_diarias[['total_dias', 'dias_sem_chuva', 'dias_chuva_moderada', 'dias_chuva_forte', 'dias_chuva_extrema', 'vendas_medias_diarias_por_loja']]
display(analise_final_chuva_vendas_diarias_num.round(2).sort_values(by='vendas_medias_diarias_por_loja', ascending=False))
# Out:
#             total_dias  dias_sem_chuva  dias_chuva_moderada  dias_chuva_forte  \
# localidade
# Sydney            2285            1774                  292               155
# Brisbane          3029            2484                  309               162
# Melbourne         2240            1821                  306                98
# Adelaide          2746            2270                  350               113
# Perth             3049            2541                  323               159
#
#             dias_chuva_extrema  vendas_medias_diarias_por_loja
# localidade
# Sydney                      64                         3068.43
# Brisbane                    74                         2898.42
# Melbourne                   15                         2687.14
# Adelaide                    13                         2505.73
# Perth                       26                         2459.98

# %%
# Separando porcentagem dos números
analise_final_chuva_vendas_diarias_pct = analise_final_chuva_vendas_diarias[['total_dias', '%_dias_sem_chuva', '%_dias_chuva_moderada', '%_dias_chuva_forte', '%_dias_chuva_extrema', 'vendas_medias_diarias_por_loja']]
display(analise_final_chuva_vendas_diarias_pct.round(2).sort_values(by='vendas_medias_diarias_por_loja', ascending=False))
# Out:
#             total_dias  %_dias_sem_chuva  %_dias_chuva_moderada  \
# localidade
# Sydney            2285             77.64                  12.78
# Brisbane          3029             82.01                  10.20
# Melbourne         2240             81.29                  13.66
# Adelaide          2746             82.67                  12.75
# Perth             3049             83.34                  10.59
#
#             %_dias_chuva_forte  %_dias_chuva_extrema  \
# localidade
# Sydney                    6.78                  2.80
# Brisbane                  5.35                  2.44
# Melbourne                 4.38                  0.67
# Adelaide                  4.12                  0.47
# Perth                     5.21                  0.85
#
#             vendas_medias_diarias_por_loja
# localidade
# Sydney                             3068.43
# Brisbane                           2898.42
# Melbourne                          2687.14
# Adelaide                           2505.73
# Perth                              2459.98

# %%
# Aplicando correlação
display(analise_final_chuva_vendas_diarias_pct.corr().round(2))
# Out:
#                                 total_dias  %_dias_sem_chuva  \
# total_dias                            1.00              0.73
# %_dias_sem_chuva                      0.73              1.00
# %_dias_chuva_moderada                -0.90             -0.44
# %_dias_chuva_forte                   -0.17             -0.76
# %_dias_chuva_extrema                 -0.08             -0.70
# vendas_medias_diarias_por_loja       -0.42             -0.86
#
#                                 %_dias_chuva_moderada  %_dias_chuva_forte  \
# total_dias                                      -0.90               -0.17
# %_dias_sem_chuva                                -0.44               -0.76
# %_dias_chuva_moderada                            1.00               -0.20
# %_dias_chuva_forte                              -0.20                1.00
# %_dias_chuva_extrema                            -0.29                0.87
# vendas_medias_diarias_por_loja                   0.07                0.77
#
#                                 %_dias_chuva_extrema  \
# total_dias                                     -0.08
# %_dias_sem_chuva                               -0.70
# %_dias_chuva_moderada                          -0.29
# %_dias_chuva_forte                              0.87
# %_dias_chuva_extrema                            1.00
# vendas_medias_diarias_por_loja                  0.92
#
#                                 vendas_medias_diarias_por_loja
# total_dias                                               -0.42
# %_dias_sem_chuva                                         -0.86
# %_dias_chuva_moderada                                     0.07
# %_dias_chuva_forte                                        0.77
# %_dias_chuva_extrema                                      0.92
# vendas_medias_diarias_por_loja                            1.00

# %%
corr = analise_final_chuva_vendas_diarias_pct.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', center=0)

plt.title('Matriz de Correlação — Clima vs Vendas Médias Diárias')
plt.tight_layout()
plt.show()

# %%
"""
analise_chuva_vd_num_corr = analise_final_chuva_vendas_diarias_num.corr()
display(analise_chuva_vd_num_corr.round(2)) 
"""
display(df_clima)
# Out:
#              data localidade  temp_min  temp_max  chuva_mm  evaporacao  \
# 0      2010-10-08     Sydney      13.8      19.5       0.0         4.6
# 1      2010-10-11     Sydney      16.5      21.1       1.2         6.2
# 2      2010-10-12     Sydney      16.4      21.8       1.0         6.0
# 3      2010-10-13     Sydney      16.7      23.9       0.4         7.0
# 4      2010-10-14     Sydney      17.8      28.9       2.0         4.0
# ...           ...        ...       ...       ...       ...         ...
# 13344  2017-06-21      Perth      10.3      19.9       0.2         1.8
# 13345  2017-06-22      Perth      13.0      16.8      61.2         3.6
# 13346  2017-06-23      Perth      13.3      18.9       0.4         1.8
# 13347  2017-06-24      Perth      11.5      18.2       0.0         3.8
# 13348  2017-06-25      Perth       6.3      17.0       0.0         1.6
#
#        horas_sol vento_rajada_direcao  vento_rajada_velocidade  \
# 0            9.5                  ESE                     35.0
# 1            6.6                  ENE                     56.0
# 2            5.9                  NNE                     50.0
# 3            2.8                  NNE                     39.0
# 4           10.8                  NNW                     41.0
# ...          ...                  ...                      ...
# 13344        7.5                   NW                     37.0
# 13345        0.0                  SSW                     46.0
# 13346        6.5                   SE                     37.0
# 13347        9.3                   SE                     30.0
# 13348        7.9                    E                     26.0
#
#       vento_direcao_9h  ... cluster_temp_9h  cluster_temp_15h  \
# 0                  NNE  ...           ameno             ameno
# 1                   NE  ...           ameno            quente
# 2                  NNE  ...           ameno            quente
# 3                    W  ...           ameno            quente
# 4                  NNW  ...          quente            quente
# ...                ...  ...             ...               ...
# 13344              NNE  ...           ameno             ameno
# 13345                W  ...           ameno             ameno
# 13346               SE  ...           ameno             ameno
# 13347              ESE  ...           ameno             ameno
# 13348               SE  ...           ameno             ameno
#
#        cluster_umidade_9h  cluster_umidade_15h  cluster_chuva_mm  \
# 0                tropical                ameno              seco
# 1                   ameno                ameno              seco
# 2                tropical                ameno              seco
# 3                tropical                ameno              seco
# 4                   ameno                ameno              seco
# ...                   ...                  ...               ...
# 13344            tropical                ameno              seco
# 13345            tropical             tropical           extrema
# 13346            tropical                ameno              seco
# 13347               ameno                ameno              seco
# 13348            tropical                ameno              seco
#
#        cluster_rajada_vento     cluster_hora_sol  cluster_pressao_at_9h  \
# 0                  moderado  muitas horas de sol                 normal
# 1                     forte  médias horas de sol                 normal
# 2                     forte  médias horas de sol                 normal
# 3                  moderado  poucas horas de sol                 normal
# 4                     forte  muitas horas de sol                 normal
# ...                     ...                  ...                    ...
# 13344              moderado  médias horas de sol                 normal
# 13345                 forte  poucas horas de sol                  baixa
# 13346              moderado  médias horas de sol                   alta
# 13347              moderado  muitas horas de sol                   alta
# 13348              moderado  médias horas de sol                   alta
#
#        cluster_pressao_at_15h      cluster_nuvem_9h
# 0                      normal  parcialmente nublado
# 1                      normal  parcialmente nublado
# 2                      normal  parcialmente nublado
# 3                      normal  parcialmente nublado
# 4                       baixa  parcialmente nublado
# ...                       ...                   ...
# 13344                  normal  parcialmente nublado
# 13345                   baixa  parcialmente nublado
# 13346                    alta  parcialmente nublado
# 13347                    alta  parcialmente nublado
# 13348                    alta  parcialmente nublado
#
# [13349 rows x 38 columns]

# %%
# Horas Sol vs vendas médias diárias - Existe influencia?

# Horas sol // cidade

# var recebe = df_clima onde filtrado por df_clima coluna cluster_hora_sol = texto filtrado // agrupa por localidade // conta o número de linhas (tamanho) da localidade e renomeia para min_hora_sol
min_horas_sol = (df_clima[df_clima['cluster_hora_sol'] == 'poucas horas de sol'].groupby('localidade').size().rename('min_hora_sol'))
med_horas_sol = (df_clima[df_clima['cluster_hora_sol'] == 'médias horas de sol'].groupby('localidade').size().rename('med_hora_sol'))
max_horas_sol = (df_clima[df_clima['cluster_hora_sol'] == 'muitas horas de sol'].groupby('localidade').size().rename('max_hora_sol'))


# Merge // join dos dados
horas_sol = [min_horas_sol, med_horas_sol, max_horas_sol]
horas_sol_analise = total_dias.to_frame().join(horas_sol, how='left')

# Porcentagem horas sol
horas_sol_analise['%_min_horas_sol'] = (horas_sol_analise['min_hora_sol'] / horas_sol_analise['total_dias'] * 100)
horas_sol_analise['%_med_horas_sol'] = (horas_sol_analise['med_hora_sol'] / horas_sol_analise['total_dias'] * 100)
horas_sol_analise['%_max_horas_sol'] = (horas_sol_analise['max_hora_sol'] / horas_sol_analise['total_dias'] * 100)


# Agrupando vendas médias diárias por cidade
vendas_por_cidade = (df_retail.groupby('localidade')['vendas_medias_diarias'].mean().rename('vendas_medias_diarias_por_loja'))

# Merge // join dos dados de retail e clima
analise_final_horas_sol_vendas_diarias = horas_sol_analise.join(vendas_por_cidade, how='left')

# Imprime
display(analise_final_horas_sol_vendas_diarias.round(2).sort_values(by='vendas_medias_diarias_por_loja', ascending=False))
# Out:
#             total_dias  min_hora_sol  med_hora_sol  max_hora_sol  \
# localidade
# Sydney            2285           618           747           920
# Brisbane          3029           548           904          1577
# Melbourne         2240           741           853           646
# Adelaide          2746           387          1706           653
# Perth             3049           425           976          1648
#
#             %_min_horas_sol  %_med_horas_sol  %_max_horas_sol  \
# localidade
# Sydney                27.05            32.69            40.26
# Brisbane              18.09            29.84            52.06
# Melbourne             33.08            38.08            28.84
# Adelaide              14.09            62.13            23.78
# Perth                 13.94            32.01            54.05
#
#             vendas_medias_diarias_por_loja
# localidade
# Sydney                             3068.43
# Brisbane                           2898.42
# Melbourne                          2687.14
# Adelaide                           2505.73
# Perth                              2459.98

# %%
# Gráfico

plot_df = analise_final_horas_sol_vendas_diarias.reset_index()

fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)

pares = [
    ('%_min_horas_sol', 'Poucas horas de sol'),
    ('%_med_horas_sol', 'Médias horas de sol'),
    ('%_max_horas_sol', 'Muitas horas de sol'),
]

for ax, (col, titulo) in zip(axes, pares):
    sns.regplot(
        data=plot_df,
        x=col,
        y='vendas_medias_diarias_por_loja',
        ax=ax
    )

    ax.set_title(titulo)
    ax.set_xlabel('% de dias')
    ax.set_ylabel('Média de vendas diárias')

    # rótulos das cidades
    for _, row in plot_df.iterrows():
        ax.text(
            row[col],
            row['vendas_medias_diarias_por_loja'],
            str(row['localidade']),
            fontsize=9,
            ha='left',
            va='bottom'
        )

plt.suptitle('Horas de Sol vs Média de Vendas Diárias por Localidade', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.92])
plt.show()

# %%
# Separando colunas %
analise_final_horas_sol_vendas_diarias_pct = analise_final_horas_sol_vendas_diarias[["total_dias", "%_min_horas_sol", "%_med_horas_sol", "%_max_horas_sol", "vendas_medias_diarias_por_loja"]]
display(analise_final_horas_sol_vendas_diarias_pct.round(2).sort_values(by='vendas_medias_diarias_por_loja', ascending=False))
# Out:
#             total_dias  %_min_horas_sol  %_med_horas_sol  %_max_horas_sol  \
# localidade
# Sydney            2285            27.05            32.69            40.26
# Brisbane          3029            18.09            29.84            52.06
# Melbourne         2240            33.08            38.08            28.84
# Adelaide          2746            14.09            62.13            23.78
# Perth             3049            13.94            32.01            54.05
#
#             vendas_medias_diarias_por_loja
# localidade
# Sydney                             3068.43
# Brisbane                           2898.42
# Melbourne                          2687.14
# Adelaide                           2505.73
# Perth                              2459.98

# %%
# Aplicando correlação
display(analise_final_horas_sol_vendas_diarias_pct.corr().round(2))
# Out:
#                                 total_dias  %_min_horas_sol  %_med_horas_sol  \
# total_dias                            1.00            -0.89            -0.07
# %_min_horas_sol                      -0.89             1.00            -0.29
# %_med_horas_sol                      -0.07            -0.29             1.00
# %_max_horas_sol                       0.62            -0.34            -0.80
# vendas_medias_diarias_por_loja       -0.42             0.51            -0.50
#
#                                 %_max_horas_sol  \
# total_dias                                 0.62
# %_min_horas_sol                           -0.34
# %_med_horas_sol                           -0.80
# %_max_horas_sol                            1.00
# vendas_medias_diarias_por_loja             0.17
#
#                                 vendas_medias_diarias_por_loja
# total_dias                                               -0.42
# %_min_horas_sol                                           0.51
# %_med_horas_sol                                          -0.50
# %_max_horas_sol                                           0.17
# vendas_medias_diarias_por_loja                            1.00

# %%
# Gráfico

corr2 = analise_final_horas_sol_vendas_diarias_pct.corr()

plt.figure(figsize=(7, 5))
sns.heatmap(corr2, annot=True, fmt='.2f', center=0, cmap='coolwarm')

plt.title('Correlação — Horas de Sol vs Vendas Médias Diárias')
plt.tight_layout()
plt.show()

# %%
display(df_clima), display(df_retail)
# Out:
#              data localidade  temp_min  temp_max  chuva_mm  evaporacao  \
# 0      2010-10-08     Sydney      13.8      19.5       0.0         4.6
# 1      2010-10-11     Sydney      16.5      21.1       1.2         6.2
# 2      2010-10-12     Sydney      16.4      21.8       1.0         6.0
# 3      2010-10-13     Sydney      16.7      23.9       0.4         7.0
# 4      2010-10-14     Sydney      17.8      28.9       2.0         4.0
# ...           ...        ...       ...       ...       ...         ...
# 13344  2017-06-21      Perth      10.3      19.9       0.2         1.8
# 13345  2017-06-22      Perth      13.0      16.8      61.2         3.6
# 13346  2017-06-23      Perth      13.3      18.9       0.4         1.8
# 13347  2017-06-24      Perth      11.5      18.2       0.0         3.8
# 13348  2017-06-25      Perth       6.3      17.0       0.0         1.6
#
#        horas_sol vento_rajada_direcao  vento_rajada_velocidade  \
# 0            9.5                  ESE                     35.0
# 1            6.6                  ENE                     56.0
# 2            5.9                  NNE                     50.0
# 3            2.8                  NNE                     39.0
# 4           10.8                  NNW                     41.0
# ...          ...                  ...                      ...
# 13344        7.5                   NW                     37.0
# 13345        0.0                  SSW                     46.0
# 13346        6.5                   SE                     37.0
# 13347        9.3                   SE                     30.0
# 13348        7.9                    E                     26.0
#
#       vento_direcao_9h  ... cluster_temp_9h  cluster_temp_15h  \
# 0                  NNE  ...           ameno             ameno
# 1                   NE  ...           ameno            quente
# 2                  NNE  ...           ameno            quente
# 3                    W  ...           ameno            quente
# 4                  NNW  ...          quente            quente
# ...                ...  ...             ...               ...
# 13344              NNE  ...           ameno             ameno
# 13345                W  ...           ameno             ameno
# 13346               SE  ...           ameno             ameno
# 13347              ESE  ...           ameno             ameno
# 13348               SE  ...           ameno             ameno
#
#        cluster_umidade_9h  cluster_umidade_15h  cluster_chuva_mm  \
# 0                tropical                ameno              seco
# 1                   ameno                ameno              seco
# 2                tropical                ameno              seco
# 3                tropical                ameno              seco
# 4                   ameno                ameno              seco
# ...                   ...                  ...               ...
# 13344            tropical                ameno              seco
# 13345            tropical             tropical           extrema
# 13346            tropical                ameno              seco
# 13347               ameno                ameno              seco
# 13348            tropical                ameno              seco
#
#        cluster_rajada_vento     cluster_hora_sol  cluster_pressao_at_9h  \
# 0                  moderado  muitas horas de sol                 normal
# 1                     forte  médias horas de sol                 normal
# 2                     forte  médias horas de sol                 normal
# 3                  moderado  poucas horas de sol                 normal
# 4                     forte  muitas horas de sol                 normal
# ...                     ...                  ...                    ...
# 13344              moderado  médias horas de sol                 normal
# 13345                 forte  poucas horas de sol                  baixa
# 13346              moderado  médias horas de sol                   alta
# 13347              moderado  muitas horas de sol                   alta
# 13348              moderado  médias horas de sol                   alta
#
#        cluster_pressao_at_15h      cluster_nuvem_9h
# 0                      normal  parcialmente nublado
# 1                      normal  parcialmente nublado
# 2                      normal  parcialmente nublado
# 3                      normal  parcialmente nublado
# 4                       baixa  parcialmente nublado
# ...                       ...                   ...
# 13344                  normal  parcialmente nublado
# 13345                   baixa  parcialmente nublado
# 13346                    alta  parcialmente nublado
# 13347                    alta  parcialmente nublado
# 13348                    alta  parcialmente nublado
#
# [13349 rows x 38 columns]
#     tipo_negocio     loja_negocio localidade horario_abertura  \
# 0       Clothing      Fashion Hub  Melbourne         09:00:00
# 1      Bookstore        Book Nook   Brisbane         09:00:00
# 2      Bookstore        Book Nook   Adelaide         08:00:00
# 3      Bookstore        Book Nook  Melbourne         09:00:00
# 4      Furniture  Home Essentials     Sydney         07:00:00
# ..           ...              ...        ...              ...
# 495     Clothing      Fashion Hub  Melbourne         07:00:00
# 496      Grocery    Green Grocers     Sydney         08:00:00
# 497     Clothing      Fashion Hub      Perth         07:00:00
# 498     Clothing      Fashion Hub     Sydney         08:00:00
# 499    Bookstore        Book Nook     Sydney         10:00:00
#
#     horario_fechamento horario_maior_fluxo horario_pico_vendas  \
# 0             20:00:00            19:00:00            16:00:00
# 1             22:00:00            14:00:00            18:00:00
# 2             21:00:00            16:00:00            19:00:00
# 3             18:00:00            18:00:00            19:00:00
# 4             20:00:00            15:00:00            21:00:00
# ..                 ...                 ...                 ...
# 495           20:00:00            18:00:00            17:00:00
# 496           18:00:00            11:00:00            17:00:00
# 497           21:00:00            12:00:00            20:00:00
# 498           19:00:00            20:00:00            17:00:00
# 499           21:00:00            13:00:00            21:00:00
#
#     alocacao_funcionarios horario_pico_vendas_2  vendas_medias_diarias  \
# 0             Overstaffed              20:00:00                3520.77
# 1            Understaffed              17:00:00                2915.36
# 2             Overstaffed              18:00:00                1984.46
# 3             Overstaffed              19:00:00                 644.22
# 4            Understaffed              18:00:00                 620.63
# ..                    ...                   ...                    ...
# 495           Overstaffed              20:00:00                 507.56
# 496          Understaffed              17:00:00                3618.03
# 497           Overstaffed              20:00:00                1569.51
# 498          Understaffed              19:00:00                1411.71
# 499           Overstaffed              17:00:00                2615.05
#
#      vendas_medias_semanais             produtos_populares perfil_clientes  \
# 0                  23527.26                T-shirts, Jeans    Young Adults
# 1                  27744.20  Children's Books, Non-fiction           Teens
# 2                  22411.88  Non-fiction, Children's Books           Teens
# 3                  31314.84           Fiction, Non-fiction           Teens
# 4                  27881.23                  Chairs, Sofas         Seniors
# ..                      ...                            ...             ...
# 495                 5081.61                 Dresses, Jeans    Young Adults
# 496                29709.42     Vegetables, Dairy Products        Families
# 497                 9908.53                 Dresses, Jeans    Young Adults
# 498                33851.77                T-shirts, Jeans    Young Adults
# 499                31314.89      Fiction, Children's Books           Teens
#
#     metodos_pagamento satisfacao_clientes lucratividade_loja  \
# 0         Credit Card                Good          Decreased
# 1         Credit Card                Good          Decreased
# 2         Credit Card                 Bad          Decreased
# 3      Digital Wallet                 Bad          Decreased
# 4                Cash                Good          Increased
# ..                ...                 ...                ...
# 495    Digital Wallet                Good          Increased
# 496        Debit Card                 Bad          Increased
# 497    Digital Wallet                Good          Increased
# 498       Credit Card                Good          Increased
# 499    Digital Wallet                Good          Increased
#
#     satisfacao_funcionarios reclamacoes_trabalhistas
# 0              Dissatisfied                      Yes
# 1              Dissatisfied                      Yes
# 2                 Satisfied                       No
# 3              Dissatisfied                      Yes
# 4                 Satisfied                       No
# ..                      ...                      ...
# 495               Satisfied                       No
# 496               Satisfied                      Yes
# 497            Dissatisfied                       No
# 498            Dissatisfied                      Yes
# 499            Dissatisfied                      Yes
#
# [500 rows x 18 columns]
# (None, None)

# %%
df_retail.describe()
# Out:
#        vendas_medias_diarias  vendas_medias_semanais
# count             500.000000              500.000000
# mean             2748.050040            21274.825640
# std              1163.109471             9397.319614
# min               494.540000             3865.030000
# 25%              1868.622500            13966.630000
# 50%              2785.035000            23320.345000
# 75%              3698.420000            29865.052500
# max              5199.460000            37754.760000
