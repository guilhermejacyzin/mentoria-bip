# %%
# Imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
import json
import requests
import datetime

# %% [markdown]
# ### Leitura Geral dos Dataset's

# %%
df_clima = pd.read_csv(r'C:\Users\JacyzinGuilherme(Bip\mentoria-bip\dados_brutos\clima_australia.csv')
display(df_clima)
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
# Renomear as colunas para pt-br
df_clima = df_clima.rename(columns={
    "Date": "data",
    "Location": "localidade",
    "MinTemp": "temperatura_minima",
    "MaxTemp": "temperatura_maxima",
    "Rainfall": "chuva_mm",
    "Evaporation": "evaporacao_mm",
    "Sunshine": "horas_sol",
    "WindGustDir": "direcao_rajada_maxima",
    "WindGustSpeed": "velocidade_rajada_maxima",
    "WindDir9am": "direcao_vento_9h",
    "WindDir3pm": "direcao_vento_15h",
    "WindSpeed9am": "velocidade_vento_9h",
    "WindSpeed3pm": "velocidade_vento_15h",
    "Humidity9am": "umidade_9h",
    "Humidity3pm": "umidade_15h",
    "Pressure9am": "pressao_9h",
    "Pressure3pm": "pressao_15h",
    "Cloud9am": "nuvens_9h",
    "Cloud3pm": "nuvens_15h",
    "Temp9am": "temperatura_9h",
    "Temp3pm": "temperatura_15h",
    "RainToday": "choveu_hoje",
    "RainTomorrow": "vai_chover_amanha"
})

df_clima.head(5)
# Out:
#          data localidade  temperatura_minima  temperatura_maxima  chuva_mm  \
# 0  2008-12-01     Albury                13.4                22.9       0.6
# 1  2008-12-02     Albury                 7.4                25.1       0.0
# 2  2008-12-03     Albury                12.9                25.7       0.0
# 3  2008-12-04     Albury                 9.2                28.0       0.0
# 4  2008-12-05     Albury                17.5                32.3       1.0
#
#    evaporacao_mm  horas_sol direcao_rajada_maxima  velocidade_rajada_maxima  \
# 0            NaN        NaN                     W                      44.0
# 1            NaN        NaN                   WNW                      44.0
# 2            NaN        NaN                   WSW                      46.0
# 3            NaN        NaN                    NE                      24.0
# 4            NaN        NaN                     W                      41.0
#
# ...

# %%
df_clima.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   data                      145460 non-null  object
#  1   localidade                145460 non-null  object
#  2   temperatura_minima        143975 non-null  float64
#  3   temperatura_maxima        144199 non-null  float64
#  4   chuva_mm                  142199 non-null  float64
#  5   evaporacao_mm             82670 non-null   float64
#  6   horas_sol                 75625 non-null   float64
#  7   direcao_rajada_maxima     135134 non-null  object
#  8   velocidade_rajada_maxima  135197 non-null  float64
#  9   direcao_vento_9h          134894 non-null  object
#  10  direcao_vento_15h         141232 non-null  object
#  11  velocidade_vento_9h       143693 non-null  float64
#  12  velocidade_vento_15h      142398 non-null  float64
# ...

# %%
df_clima.columns
# Out:
# Index(['data', 'localidade', 'temperatura_minima', 'temperatura_maxima',
#        'chuva_mm', 'evaporacao_mm', 'horas_sol', 'direcao_rajada_maxima',
#        'velocidade_rajada_maxima', 'direcao_vento_9h', 'direcao_vento_15h',
#        'velocidade_vento_9h', 'velocidade_vento_15h', 'umidade_9h',
#        'umidade_15h', 'pressao_9h', 'pressao_15h', 'nuvens_9h', 'nuvens_15h',
#        'temperatura_9h', 'temperatura_15h', 'choveu_hoje',
#        'vai_chover_amanha'],
#       dtype='object')

# %%
df_clima.describe()
# Out:
#        temperatura_minima  temperatura_maxima       chuva_mm  evaporacao_mm  \
# count       143975.000000       144199.000000  142199.000000   82670.000000
# mean            12.194034           23.221348       2.360918       5.468232
# std              6.398495            7.119049       8.478060       4.193704
# min             -8.500000           -4.800000       0.000000       0.000000
# 25%              7.600000           17.900000       0.000000       2.600000
# 50%             12.000000           22.600000       0.000000       4.800000
# 75%             16.900000           28.200000       0.800000       7.400000
# max             33.900000           48.100000     371.000000     145.000000
#
#           horas_sol  velocidade_rajada_maxima  velocidade_vento_9h  \
# count  75625.000000             135197.000000        143693.000000
# mean       7.611178                 40.035230            14.043426
# std        3.785483                 13.607062             8.915375
# ...

# %%
tipos_dados_df_clima = df_clima.dtypes
print(tipos_dados_df_clima)
# Out:
# data                         object
# localidade                   object
# temperatura_minima          float64
# temperatura_maxima          float64
# chuva_mm                    float64
# evaporacao_mm               float64
# horas_sol                   float64
# direcao_rajada_maxima        object
# velocidade_rajada_maxima    float64
# direcao_vento_9h             object
# direcao_vento_15h            object
# velocidade_vento_9h         float64
# velocidade_vento_15h        float64
# umidade_9h                  float64
# umidade_15h                 float64
# pressao_9h                  float64
# pressao_15h                 float64
# nuvens_9h                   float64
# nuvens_15h                  float64
# temperatura_9h              float64
# temperatura_15h             float64
# choveu_hoje                  object
# vai_chover_amanha            object
# dtype: object

# %%
# Importação do dataset retail
df_retail = pd.read_excel(r'C:\Users\JacyzinGuilherme(Bip\mentoria-bip\dados_brutos\australia_retail.xlsx')
display(df_retail)
# Out:
#     Type of Business    Business Name   Location Opening Time Closing Time  \
# 0           Clothing      Fashion Hub  Melbourne      9:00 AM      8:00 PM
# 1          Bookstore        Book Nook   Brisbane      9:00 AM     10:00 PM
# 2          Bookstore        Book Nook   Adelaide      8:00 AM      9:00 PM
# 3          Bookstore        Book Nook  Melbourne      9:00 AM      6:00 PM
# 4          Furniture  Home Essentials     Sydney      7:00 AM      8:00 PM
# ..               ...              ...        ...          ...          ...
# 495         Clothing      Fashion Hub  Melbourne      7:00 AM      8:00 PM
# 496          Grocery    Green Grocers     Sydney      8:00 AM      6:00 PM
# 497         Clothing      Fashion Hub      Perth      7:00 AM      9:00 PM
# 498         Clothing      Fashion Hub     Sydney      8:00 AM      7:00 PM
# 499        Bookstore        Book Nook     Sydney     10:00 AM      9:00 PM
#
# ...

# %%
# Renomear colunas para pt-br
df_retail = df_retail.rename(columns={
    "Type of Business": "tipo_negocio",
    "Business Name": "nome_estabelecimento",
    "Location": "localidade",
    "Opening Time": "horario_abertura",
    "Closing Time": "horario_fechamento",
    "Most Traffic Occurring Time": "horario_maior_fluxo",
    "Maximum Sales Time": "horario_pico_vendas",
    "Maximum Sales Time.1": "horario_pico_vendas_2",
    "Employee Scheduling": "alocacao_funcionarios",
    "Employee Satisfaction": "satisfacao_funcionarios",
    "Daily Average Sales": "vendas_medias_diarias",
    "Weekly Average Sales": "vendas_medias_semanais",
    "Store Profitability": "lucratividade_loja",
    "Popular Products Sold": "produtos_populares",
    "Customer Demographics": "perfil_clientes",
    "Payment Methods": "metodos_pagamento",
    "Customer Satisfaction": "satisfacao_clientes",
    "Labour Law Complaints": "reclamacoes_trabalhistas"
})

# Mostrar as novas colunas
df_retail.head()
# Out:
#   tipo_negocio nome_estabelecimento localidade horario_abertura  \
# 0     Clothing          Fashion Hub  Melbourne          9:00 AM
# 1    Bookstore            Book Nook   Brisbane          9:00 AM
# 2    Bookstore            Book Nook   Adelaide          8:00 AM
# 3    Bookstore            Book Nook  Melbourne          9:00 AM
# 4    Furniture      Home Essentials     Sydney          7:00 AM
#
#   horario_fechamento horario_maior_fluxo horario_pico_vendas  \
# 0            8:00 PM            19:00 PM            16:00 PM
# 1           10:00 PM            14:00 PM            18:00 PM
# 2            9:00 PM            16:00 PM            19:00 PM
# 3            6:00 PM            18:00 PM            19:00 PM
# 4            8:00 PM            15:00 PM            21:00 PM
#
#   alocacao_funcionarios horario_pico_vendas_2  vendas_medias_diarias  \
# 0           Overstaffed               8:00 PM                3520.77
# 1          Understaffed               5:00 PM                2915.36
# ...

# %%
# Verificação das colunas
df_retail.columns
# Out:
# Index(['tipo_negocio', 'nome_estabelecimento', 'localidade',
#        'horario_abertura', 'horario_fechamento', 'horario_maior_fluxo',
#        'horario_pico_vendas', 'alocacao_funcionarios', 'horario_pico_vendas_2',
#        'vendas_medias_diarias', 'vendas_medias_semanais', 'produtos_populares',
#        'perfil_clientes', 'metodos_pagamento', 'satisfacao_clientes',
#        'lucratividade_loja', 'satisfacao_funcionarios',
#        'reclamacoes_trabalhistas'],
#       dtype='object')

# %%
# Informações gerais do dataset
df_retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   tipo_negocio              500 non-null    object
#  1   nome_estabelecimento      500 non-null    object
#  2   localidade                500 non-null    object
#  3   horario_abertura          500 non-null    object
#  4   horario_fechamento        500 non-null    object
#  5   horario_maior_fluxo       500 non-null    object
#  6   horario_pico_vendas       500 non-null    object
#  7   alocacao_funcionarios     500 non-null    object
#  8   horario_pico_vendas_2     500 non-null    object
#  9   vendas_medias_diarias     500 non-null    float64
#  10  vendas_medias_semanais    500 non-null    float64
#  11  produtos_populares        500 non-null    object
#  12  perfil_clientes           500 non-null    object
# ...

# %%
# Tipos de dados das colunas
tipos_dados_df_retail = df_retail.dtypes
print(tipos_dados_df_retail)
# Out:
# tipo_negocio                 object
# nome_estabelecimento         object
# localidade                   object
# horario_abertura             object
# horario_fechamento           object
# horario_maior_fluxo          object
# horario_pico_vendas          object
# alocacao_funcionarios        object
# horario_pico_vendas_2        object
# vendas_medias_diarias       float64
# vendas_medias_semanais      float64
# produtos_populares           object
# perfil_clientes              object
# metodos_pagamento            object
# satisfacao_clientes          object
# lucratividade_loja           object
# satisfacao_funcionarios      object
# reclamacoes_trabalhistas     object
# dtype: object

# %%
# Estatísticas gerais
df_retail.describe()
# Out:
#        vendas_medias_diarias  vendas_medias_semanais
# count             500.000000              500.000000
# mean             2748.050040            21274.825640
# std              1163.109471             9397.319614
# min               494.540000             3865.030000
# 25%              1868.622500            13966.630000
# 50%              2785.035000            23320.345000
# 75%              3698.420000            29865.052500
# max              5199.460000            37754.760000

# %%
# Contando o número de nulos em cada coluna df_retail

df_clima.isnull().sum()
# Out:
# data                            0
# localidade                      0
# temperatura_minima           1485
# temperatura_maxima           1261
# chuva_mm                     3261
# evaporacao_mm               62790
# horas_sol                   69835
# direcao_rajada_maxima       10326
# velocidade_rajada_maxima    10263
# direcao_vento_9h            10566
# direcao_vento_15h            4228
# velocidade_vento_9h          1767
# velocidade_vento_15h         3062
# umidade_9h                   2654
# umidade_15h                  4507
# pressao_9h                  15065
# pressao_15h                 15028
# nuvens_9h                   55888
# nuvens_15h                  59358
# temperatura_9h               1767
# temperatura_15h              3609
# choveu_hoje                  3261
# vai_chover_amanha            3267
# dtype: int64

# %%
# Contando o número de nulos em cada coluna df_retail

df_retail.isnull().sum()
# Out:
# tipo_negocio                0
# nome_estabelecimento        0
# localidade                  0
# horario_abertura            0
# horario_fechamento          0
# horario_maior_fluxo         0
# horario_pico_vendas         0
# alocacao_funcionarios       0
# horario_pico_vendas_2       0
# vendas_medias_diarias       0
# vendas_medias_semanais      0
# produtos_populares          0
# perfil_clientes             0
# metodos_pagamento           0
# satisfacao_clientes         0
# lucratividade_loja          0
# satisfacao_funcionarios     0
# reclamacoes_trabalhistas    0
# dtype: int64

# %%
display(df_clima)
# Out:
#               data localidade  temperatura_minima  temperatura_maxima  \
# 0       2008-12-01     Albury                13.4                22.9
# 1       2008-12-02     Albury                 7.4                25.1
# 2       2008-12-03     Albury                12.9                25.7
# 3       2008-12-04     Albury                 9.2                28.0
# 4       2008-12-05     Albury                17.5                32.3
# ...            ...        ...                 ...                 ...
# 145455  2017-06-21      Uluru                 2.8                23.4
# 145456  2017-06-22      Uluru                 3.6                25.3
# 145457  2017-06-23      Uluru                 5.4                26.9
# 145458  2017-06-24      Uluru                 7.8                27.0
# 145459  2017-06-25      Uluru                14.9                 NaN
#
#         chuva_mm  evaporacao_mm  horas_sol direcao_rajada_maxima  \
# ...

# %%
display(df_retail)
# Out:
#     tipo_negocio nome_estabelecimento localidade horario_abertura  \
# 0       Clothing          Fashion Hub  Melbourne          9:00 AM
# 1      Bookstore            Book Nook   Brisbane          9:00 AM
# 2      Bookstore            Book Nook   Adelaide          8:00 AM
# 3      Bookstore            Book Nook  Melbourne          9:00 AM
# 4      Furniture      Home Essentials     Sydney          7:00 AM
# ..           ...                  ...        ...              ...
# 495     Clothing          Fashion Hub  Melbourne          7:00 AM
# 496      Grocery        Green Grocers     Sydney          8:00 AM
# 497     Clothing          Fashion Hub      Perth          7:00 AM
# 498     Clothing          Fashion Hub     Sydney          8:00 AM
# 499    Bookstore            Book Nook     Sydney         10:00 AM
#
#     horario_fechamento horario_maior_fluxo horario_pico_vendas  \
# 0              8:00 PM            19:00 PM            16:00 PM
# ...

# %%
df_clima.shape
# Out:
# (145460, 23)

# %%
df_retail.shape
# Out:
# (500, 18)
